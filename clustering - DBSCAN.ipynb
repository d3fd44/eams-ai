# %%
from sklearn.cluster import DBSCAN
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./data-500k/data.csv")
df = df[df.columns[:-1]]
X = df[df.columns]

# %%
dbscan = DBSCAN(eps=0.05)

# %%
# this fu**s my RAM
# holy shi the first time my laptop used swap memory
# dbscan.fit(X)

# %%
np.unique(dbscan.labels_)
